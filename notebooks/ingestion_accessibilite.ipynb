# %%
import yaml
import pandas as pd
import requests
import zipfile
import io
import boto3

# %%
s3_client = boto3.client('s3')

# %%
file = open("../config/config.yaml")
yaml_file = yaml.safe_load(file)
file.close()

# %%
url = yaml_file['Lambda']['URL_API_ACCESS'] #on stocke l'url de l'API
bronze_path = yaml_file['S3']['chemins_dossiers']['bronze'] #chemin des fichiers en bronze
bucket = yaml_file['S3']['bucket'] #chemin du fichier
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 url = yaml_file['Lambda']['URL_API_ACCESS'] #on stocke l'url de l'API
#       2 bronze_path = yaml_file['S3']['chemins_dossiers']['bronze'] #chemin des fichiers en bronze
#       3 bucket = yaml_file['S3']['bucket'] #chemin du fichier
#
# KeyError: 'URL_API_ACCESS'
